# %% [markdown]
# # Organize model files into SHARED folder in /hpc/group/igvf/
#
# ## Best models from each training run:
#
# ### K562:
# * 1Kbp - Run 3
# * MSELoss - Run 2
# - CustomLoss - Run 7
# - Transformer-Encoder (TE) - Run 6
# - Biased downsampling - Run 1
# - Unbiased downsampling:
#     * 0.8M - Run 10
#     * 1M - Run 10
#     * 1.3M - Run 5
#     * 1.5M - Run 9
# - DeepSTARR architecture using BlueSTARR code - Run 4
# - Increasing layer models:
#     * 1 layer CNN - Run 1
#     * 2 layer CNN - Run 2
#     * 3 layer CNN - Run 8
#     * 4 layer CNN - Run 1
#
# ### A549:
# * 6-layer MSE loss - Dex - Run 30
# * 6-layer MSE loss - DMSO - Run 4
# * 5-layer MSE loss - Dex - Run 18 (since run 16 did not converge, ran 2 additional models to confirm if their validation loss is better than run 18 - that way making the total number of runs be 30)
# * 5-layer MSE loss - DMSO - Run 20

# %%
# %%bash
# ln -s /hpc/group/igvf/revathy/models/K562/1000bp/new/K562_1000bp-3.h5 /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/1Kbp/K562_1000bp-3.h5
# ln -s /hpc/group/igvf/revathy/models/K562/1000bp/new/K562_1000bp-3.json /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/1Kbp/K562_1000bp-3.json
# ln -s /hpc/group/igvf/revathy/models/K562/1000bp/new/K562_1000bp-3.txt /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/1Kbp/K562_1000bp-3.txt
# ln -s /hpc/group/igvf/revathy/models/K562/configs/K562-MSELoss-1000bp.config /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/1Kbp/K562-MSELoss-1000bp.config

# %%
# %%bash
# rm /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/MSELoss/K562-2.h5 \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/MSELoss/K562-2.json \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/MSELoss/K562-2.txt \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/MSELoss/K562-MSELoss.config \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/TE/K562_TE-6.h5 \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/TE/K562_TE-6.json \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/TE/K562_TE-6.txt \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/TE/K562-TE.config \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/CustomLoss/K562_Custom-7.h5 \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/CustomLoss/K562_Custom-7.json \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/CustomLoss/K562_Custom-7.txt \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/CustomLoss/K562-CustomLoss.config \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Biased_downsampling/K562-1.h5 \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Biased_downsampling/K562-1.json \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Biased_downsampling/K562-1.txt \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Biased_downsampling/K562-MSELoss.config \

# %%
# %%bash
# ln -s /hpc/group/igvf/revathy/models/K562/mse_loss/K562-2.h5 /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/MSELoss/K562-2.h5
# ln -s /hpc/group/igvf/revathy/models/K562/mse_loss/K562-2.json /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/MSELoss/K562-2.json
# ln -s /hpc/group/igvf/revathy/models/K562/mse_loss/K562-2.txt /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/MSELoss/K562-2.txt
# ln -s /hpc/group/igvf/revathy/models/K562/configs/K562-MSELoss.config /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/MSELoss/K562-MSELoss.config

# %%
# %%bash
# ln -s /hpc/group/igvf/revathy/models/K562/TE/K562_TE-6.h5 /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/TE/K562_TE-6.h5
# ln -s /hpc/group/igvf/revathy/models/K562/TE/K562_TE-6.json /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/TE/K562_TE-6.json
# ln -s /hpc/group/igvf/revathy/models/K562/TE/K562_TE-6.txt /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/TE/K562_TE-6.txt
# ln -s /hpc/group/igvf/revathy/models/K562/configs/K562-TE.config /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/TE/K562-TE.config

# %%
# %%bash
# ln -s /hpc/group/igvf/revathy/models/K562/custom_loss/new/K562_Custom-7.h5 /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/CustomLoss/K562_Custom-7.h5
# ln -s /hpc/group/igvf/revathy/models/K562/custom_loss/new/K562_Custom-7.json /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/CustomLoss/K562_Custom-7.json
# ln -s /hpc/group/igvf/revathy/models/K562/custom_loss/new/K562_Custom-7.txt /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/CustomLoss/K562_Custom-7.txt
# ln -s /hpc/group/igvf/revathy/models/K562/configs/K562-CustomLoss.config /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/CustomLoss/K562-CustomLoss.config

# %%
# %%bash
# ln -s /hpc/group/igvf/revathy/models/K562/downsampled/biased/K562-1.h5 /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Biased_downsampling/K562-1.h5
# ln -s /hpc/group/igvf/revathy/models/K562/downsampled/biased/K562-1.json /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Biased_downsampling/K562-1.json
# ln -s /hpc/group/igvf/revathy/models/K562/downsampled/biased/K562-1.txt /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Biased_downsampling/K562-1.txt
# ln -s /hpc/group/igvf/revathy/models/K562/configs/K562-MSELoss.config /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Biased_downsampling/K562-MSELoss.config

# %%
# %%bash
# rm /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/DeepSTARR-BlueSTARR/K562-4.h5 \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/DeepSTARR-BlueSTARR/K562-4.txt \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/DeepSTARR-BlueSTARR/K562-4.json \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/DeepSTARR-BlueSTARR/K562_DeepSTARR.config \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/0.8M/K562-10.h5 \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/0.8M/K562-10.txt \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/0.8M/K562-10.json \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/0.8M/K562-MSELoss-downsampled0.8M.config \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/1M/K562-10.h5 \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/1M/K562-10.txt \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/1M/K562-10.json \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/1M/K562-MSELoss-downsampled1M.config \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/1.5M/K562-9.h5 \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/1.5M/K562-9.txt \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/1.5M/K562-9.json \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/1.5M/K562-MSELoss-downsampled1.5M.config \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/1.3M/K562-9.h5 \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/1.3M/K562-9.txt \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/1.3M/K562-9.json \
#     /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/1.3M/K562-MSELoss-downsampled1.3M.config

# %%
# %%bash
# ln -s /hpc/group/igvf/revathy/models/K562/DeepSTARR/K562-4.h5 /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/DeepSTARR-BlueSTARR/K562-4.h5
# ln -s /hpc/group/igvf/revathy/models/K562/DeepSTARR/K562-4.txt /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/DeepSTARR-BlueSTARR/K562-4.txt
# ln -s /hpc/group/igvf/revathy/models/K562/DeepSTARR/K562-4.json /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/DeepSTARR-BlueSTARR/K562-4.json
# ln -s /hpc/group/igvf/revathy/models/K562/configs/K562_DeepSTARR.config /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/DeepSTARR-BlueSTARR/K562_DeepSTARR.config

# %%
# %%bash
# ln -s /hpc/group/igvf/revathy/models/K562/downsampled/unbiased/800k/K562-10.h5 /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/0.8M/K562-10.h5
# ln -s /hpc/group/igvf/revathy/models/K562/downsampled/unbiased/800k/K562-10.txt /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/0.8M/K562-10.txt
# ln -s /hpc/group/igvf/revathy/models/K562/downsampled/unbiased/800k/K562-10.json /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/0.8M/K562-10.json
# ln -s /hpc/group/igvf/revathy/models/K562/configs/K562-MSELoss-downsampled800k.config /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/0.8M/K562-MSELoss-downsampled0.8M.config

# %%
# %%bash
# ln -s /hpc/group/igvf/revathy/models/K562/downsampled/unbiased/1M/K562-10.h5 /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/1M/K562-10.h5
# ln -s /hpc/group/igvf/revathy/models/K562/downsampled/unbiased/1M/K562-10.txt /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/1M/K562-10.txt
# ln -s /hpc/group/igvf/revathy/models/K562/downsampled/unbiased/1M/K562-10.json /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/1M/K562-10.json
# ln -s /hpc/group/igvf/revathy/models/K562/configs/K562-MSELoss-downsampled1M.config /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/1M/K562-MSELoss-downsampled1M.config

# %%
# %%bash
# ln -s /hpc/group/igvf/revathy/models/K562/downsampled/unbiased/1.5M/K562-9.h5 /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/1.5M/K562-9.h5
# ln -s /hpc/group/igvf/revathy/models/K562/downsampled/unbiased/1.5M/K562-9.txt /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/1.5M/K562-9.txt
# ln -s /hpc/group/igvf/revathy/models/K562/downsampled/unbiased/1.5M/K562-9.json /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/1.5M/K562-9.json
# ln -s /hpc/group/igvf/revathy/models/K562/configs/K562-MSELoss-downsampled1.5M.config /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/1.5M/K562-MSELoss-downsampled1.5M.config

# %%
# %%bash
# ln -s /hpc/group/igvf/revathy/models/K562/downsampled/unbiased/1.3M/K562-5.h5 /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/1.3M/K562-9.h5
# ln -s /hpc/group/igvf/revathy/models/K562/downsampled/unbiased/1.3M/K562-5.txt /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/1.3M/K562-9.txt
# ln -s /hpc/group/igvf/revathy/models/K562/downsampled/unbiased/1.3M/K562-5.json /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/1.3M/K562-9.json
# ln -s /hpc/group/igvf/revathy/models/K562/configs/K562-MSELoss-downsampled1.3M.config /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/K562/Unbiased_downsampling/1.3M/K562-MSELoss-downsampled1.3M.config

# %%
# %%bash
# mkdir -p /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/A549/Dex-200/5-layer
# mkdir -p /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/A549/Dex-200/6-layer
# mkdir -p /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/A549/DMSO-200/5-layer
# mkdir -p /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/A549/DMSO-200/6-layer

# %%
# %%bash
# ln -s /hpc/group/igvf/revathy/models/A549/mse_loss/Dex-200/5-layer/Dex-16.h5 /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/A549/Dex-200/5-layer/Dex-16.h5
# ln -s /hpc/group/igvf/revathy/models/A549/mse_loss/Dex-200/5-layer/Dex-16.json /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/A549/Dex-200/5-layer/Dex-16.json
# ln -s /hpc/group/igvf/revathy/models/A549/mse_loss/DMSO-200/5-layer/DMSO-20.h5 /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/A549/DMSO-200/5-layer/DMSO-20.h5
# ln -s /hpc/group/igvf/revathy/models/A549/mse_loss/DMSO-200/5-layer/DMSO-20.json /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/A549/DMSO-200/5-layer/DMSO-20.json
# ln -s /hpc/group/igvf/revathy/models/A549/mse_loss/Dex-200/6-layer/Dex-30.h5 /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/A549/Dex-200/6-layer/Dex-30.h5
# ln -s /hpc/group/igvf/revathy/models/A549/mse_loss/Dex-200/6-layer/Dex-30.json /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/A549/Dex-200/6-layer/Dex-30.json
# ln -s /hpc/group/igvf/revathy/models/A549/mse_loss/DMSO-200/6-layer/DMSO-4.h5 /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/A549/DMSO-200/6-layer/DMSO-4.h5
# ln -s /hpc/group/igvf/revathy/models/A549/mse_loss/DMSO-200/6-layer/DMSO-4.json /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/A549/DMSO-200/6-layer/DMSO-4.json

# %%
# %%bash
# ln -s /hpc/group/igvf/revathy/models/A549/configs/A549-MSELoss-5layer.config /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/A549/Dex-200/5-layer/A549-MSELoss-5layer.config
# ln -s /hpc/group/igvf/revathy/models/A549/configs/A549-MSELoss-5layer.config /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/A549/DMSO-200/5-layer/A549-MSELoss-5layer.config
# ln -s /hpc/group/igvf/revathy/models/A549/configs/A549-MSELoss-6layer.config /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/A549/Dex-200/6-layer/A549-MSELoss-6layer.config
# ln -s /hpc/group/igvf/revathy/models/A549/configs/A549-MSELoss-6layer.config /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/A549/DMSO-200/6-layer/A549-MSELoss-6layer.config

# %%
# %%bash
# ls /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/A549/Dex-200/5-layer/
# Out:
# A549-MSELoss-5layer.config
# Dex-18.h5
# Dex-18.json
# Dex-18.txt

# %%
# %%bash
# ln -s /hpc/group/igvf/revathy/models/A549/mse_loss/Dex-200/5-layer/Dex-18.h5 /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/A549/Dex-200/5-layer/Dex-18.h5
# ln -s /hpc/group/igvf/revathy/models/A549/mse_loss/Dex-200/5-layer/Dex-18.json /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/A549/Dex-200/5-layer/Dex-18.json
# ln -s /hpc/group/igvf/revathy/models/A549/mse_loss/Dex-200/5-layer/Dex-18.txt /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/A549/Dex-200/5-layer/Dex-18.txt
# ln -s /hpc/group/igvf/revathy/models/A549/configs/A549-MSELoss-5layer.config /hpc/group/igvf/SHARED/trained-models/BEST-MODELS/A549/Dex-200/5-layer/A549-MSELoss-5layer.config

# %%
# %%bash
# ls /hpc/group/igvf/revathy/models/A549/mse_loss/Dex-200/5-layer/Dex-18*
# Out:
# /hpc/group/igvf/revathy/models/A549/mse_loss/Dex-200/5-layer/Dex-18.h5
# /hpc/group/igvf/revathy/models/A549/mse_loss/Dex-200/5-layer/Dex-18.json
# /hpc/group/igvf/revathy/models/A549/mse_loss/Dex-200/5-layer/Dex-18.txt

# %%
# %%bash
# ls .snapshot
# Out:
# 24_ifsrcgroupsigvf_2025-10-22_09:54
# 24_ifsrcgroupsigvf_2025-10-23_09:54
# 24_ifsrcgroupsigvf_2025-10-24_09:54
# 24_ifsrcgroupsigvf_2025-10-25_09:54
# 24_ifsrcgroupsigvf_2025-10-26_09:54
# 24_ifsrcgroupsigvf_2025-10-27_09:54
# 24_ifsrcgroupsigvf_2025-10-28_09:54
# Index-Snapshot-Current-1752552045
# Index-Snapshot-Current-1752573607

# %%
# !ls .snapshot/24_ifsrcgroupsigvf_2025-10-28_09:54
# Out:
# ls: cannot access '.snapshot/24_ifsrcgroupsigvf_2025-10-28_09:54': No such file or directory
